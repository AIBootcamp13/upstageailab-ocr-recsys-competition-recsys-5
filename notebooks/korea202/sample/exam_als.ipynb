# %% [markdown]
# # **Commerce Purchase Behavior Prediction baseline ALS code**
# > RecSys Advanced 강의의 Commerce Purchase Behavior Prediction 대회에 참가하신 여러분 환영합니다! 🎉
# > 아래 baseline에서는 ALS 모델을 학습하고 제출 용도의 예측 파일을 생성하는 프로세스에 대해 알아보겠습니다.
#
# ## Contents
# - Prepare Environments
# - Import Library & Load Dataset
# - Train-Test Split
# - Modeling
# - Evaluation on the Validation Set
# - Inference & Save Submission File

# %% [markdown]
# ## 1. Prepare Environments
#
# * 데이터 로드를 위한 구글 드라이브를 마운트합니다.
# * 필요한 라이브러리를 설치합니다.

# %%
# 구글 드라이브 마운트, Colab을 이용하지 않는다면 패스해도 됩니다.
from google.colab import drive
drive.mount('/gdrive', force_remount=True)
drive.mount('/content/drive')
# Out:
# Mounted at /gdrive
# Mounted at /content/drive

# %%
# 구글 드라이브에 업로드된 대회 데이터를 압축 해제하고 로컬에 저장합니다.
# !wget https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000290/data/data.tar.gz
# !tar -xvf data.tar.gz > /dev/null
# Out:
# --2024-01-24 13:54:07--  https://aistages-api-public-prod.s3.amazonaws.com/app/Competitions/000290/data/data.tar.gz
# Resolving aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)... 52.219.144.30, 52.219.148.67, 52.219.202.27, ...
# Connecting to aistages-api-public-prod.s3.amazonaws.com (aistages-api-public-prod.s3.amazonaws.com)|52.219.144.30|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 400028916 (381M) [binary/octet-stream]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>] 381.50M  15.4MB/s    in 26s
#
# 2024-01-24 13:54:34 (14.5 MB/s) - ‘data.tar.gz’ saved [400028916/400028916]
#
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.quarantine'
# tar: Ignoring unknown extended header keyword 'LIBARCHIVE.xattr.com.apple.macl'

# %%
# 필요한 라이브러리를 설치합니다.
# !pip install implicit
# Out:
# Collecting implicit
#   Downloading implicit-0.7.2-cp310-cp310-manylinux2014_x86_64.whl (8.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 50.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from implicit) (1.23.5)
# Requirement already satisfied: scipy>=0.16 in /usr/local/lib/python3.10/dist-packages (from implicit) (1.11.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from implicit) (4.66.1)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.10/dist-packages (from implicit) (3.2.0)
# Installing collected packages: implicit
# Successfully installed implicit-0.7.2

# %% [markdown]
# ## 2. Import Library & Load Dataset
# * 학습에 필요한 라이브러리를 로드합니다.

# %%
import pandas as pd
import numpy as np
from scipy import sparse
from implicit.als import AlternatingLeastSquares
from tqdm import tqdm

# %%
# 데이터를 로드합니다.
df = pd.read_parquet('/content/data/train.parquet')

# %%
df.head()
# Out:
#                                 user_id                               item_id  \
# 0  0b517454-e7c3-44ec-8c39-a68ef9c0ec60  18c11cbb-a18d-4a9e-bdea-6abd3f7d3c04
# 1  215eeee5-f9c5-4213-8641-7561dbdad1b9  47c5a6da-32d0-4a29-8b51-57304f476ded
# 2  a25bf14a-49ac-49bb-87de-ee6b300f0cc4  a6d915c6-2bb7-4393-a556-c327723d3666
# 3  09ee8591-25e0-4bb4-ae24-c48ed4212e3c  0fd4da5d-989c-4a75-9ace-2b108f834c8c
# 4  7acf7c81-69f6-4aa8-b19f-8e85aeaffc28  d52d1c91-5534-4de4-aaf1-318e932e10e7
#
#                            user_session               event_time  \
# 0  ad97f19a-f5fb-41ea-a7b2-52c21fb37ab2  2019-11-16 16:31:26 UTC
# 1  6058b45b-bdb9-4d6c-b300-42dcb1cb8280  2019-11-04 18:59:50 UTC
# 2  28a8b8e3-b374-435d-9d5d-b96058ecb75b  2019-11-26 09:01:47 UTC
# 3  f2972db7-9916-4a58-b6f9-c76afde6245e  2019-11-15 16:05:34 UTC
# 4  7d46d970-b40e-4a2f-81a7-65bf23aa0aae  2019-11-16 13:14:09 UTC
#
#     category_code     brand  price event_type
# 0   apparel.shoes    kapika  72.05       view
# 1   apparel.shoes   respect  82.63       view
# 2  apparel.tshirt  goodloot  24.43       view
# 3   apparel.shoes     baden  70.79       view
# 4   apparel.shoes    rooman  53.80       view

# %%
# 사용자(user)와 아이템(item)을 인덱스로 매핑하기 위한 딕셔너리 생성
user2idx = {v: k for k, v in enumerate(df['user_id'].unique())}  # 각 사용자를 인덱스로 매핑
idx2user = {k: v for k, v in enumerate(df['user_id'].unique())}  # 각 인덱스를 사용자로 매핑
item2idx = {v: k for k, v in enumerate(df['item_id'].unique())}  # 각 아이템을 인덱스로 매핑
idx2item = {k: v for k, v in enumerate(df['item_id'].unique())}  # 각 인덱스를 아이템으로 매핑

# 사용자와 아이템을 인덱스로 변환하여 새로운 열 추가
df['user_idx'] = df['user_id'].map(user2idx)
df['item_idx'] = df['item_id'].map(item2idx)

# %%
df.head()
# Out:
#                                 user_id                               item_id  \
# 0  0b517454-e7c3-44ec-8c39-a68ef9c0ec60  18c11cbb-a18d-4a9e-bdea-6abd3f7d3c04
# 1  215eeee5-f9c5-4213-8641-7561dbdad1b9  47c5a6da-32d0-4a29-8b51-57304f476ded
# 2  a25bf14a-49ac-49bb-87de-ee6b300f0cc4  a6d915c6-2bb7-4393-a556-c327723d3666
# 3  09ee8591-25e0-4bb4-ae24-c48ed4212e3c  0fd4da5d-989c-4a75-9ace-2b108f834c8c
# 4  7acf7c81-69f6-4aa8-b19f-8e85aeaffc28  d52d1c91-5534-4de4-aaf1-318e932e10e7
#
#                            user_session               event_time  \
# 0  ad97f19a-f5fb-41ea-a7b2-52c21fb37ab2  2019-11-16 16:31:26 UTC
# 1  6058b45b-bdb9-4d6c-b300-42dcb1cb8280  2019-11-04 18:59:50 UTC
# 2  28a8b8e3-b374-435d-9d5d-b96058ecb75b  2019-11-26 09:01:47 UTC
# 3  f2972db7-9916-4a58-b6f9-c76afde6245e  2019-11-15 16:05:34 UTC
# 4  7d46d970-b40e-4a2f-81a7-65bf23aa0aae  2019-11-16 13:14:09 UTC
#
#     category_code     brand  price event_type  user_idx  item_idx
# 0   apparel.shoes    kapika  72.05       view         0         0
# 1   apparel.shoes   respect  82.63       view         1         1
# 2  apparel.tshirt  goodloot  24.43       view         2         2
# 3   apparel.shoes     baden  70.79       view         3         3
# 4   apparel.shoes    rooman  53.80       view         4         4

# %% [markdown]
# ## 3. Train-Test Split

# %%
# about 3 min
df['event_time'] = pd.to_datetime(df['event_time'], format='%Y-%m-%d %H:%M:%S %Z')
df = df.sort_values('event_time', ascending=True)

# %%
# global temporal split (90:10)
# 실습에서는 편의상 시간 순서의 90:10 split을 수행했지만, 특정 날짜를 지정해서 split 할 수도 있습니다.
# e.g., 마지막 1주일을 test set으로, 나머지는 train set으로 사용
offset = int(0.9 * len(df))
train_df, test_df = np.split(df, [offset])

# %%
train_df
# Out:
#                                       user_id  \
# 501019   24d3ec59-5019-4edd-9cbc-1b33ae7808a4
# 1166610  33210fa3-230c-4b1b-946a-2374d0b210c8
# 1166611  33210fa3-230c-4b1b-946a-2374d0b210c8
# 1166612  33210fa3-230c-4b1b-946a-2374d0b210c8
# 1204577  33210fa3-230c-4b1b-946a-2374d0b210c8
# ...                                       ...
# 7704253  18fdfeed-4bb3-4ec6-9098-1a98f1805e5d
# 7963432  47131f90-26a9-4ee0-8a4d-138d5cf5680f
# 7154584  63b4e9c8-0d95-4c68-8f69-dba286165716
# 6560355  661ffb7f-f4c8-4eaa-aa00-567ff62478d1
# 7470837  a5e64d73-7f8e-48d3-a5a5-7fbe89a60cbb
#
#                                       item_id  \
# 501019   e4c8cedc-4107-497f-b134-caf123fbe6a2
# 1166610  6612cfd9-5e1f-4f34-ad97-cd858c70a15e
# 1166611  57680301-7d01-4ed7-8d21-6a39ecb6f989
# 1166612  f0205dd1-ff73-4726-a8ba-13b6ecd34896
# 1204577  ef48c327-e9a4-415a-9a56-94b3a173fe55
# ...                                       ...
# 7704253  4cbf56fc-21ac-4549-9e3c-82af41b3f434
# 7963432  77895ee7-eb22-4c9a-95e0-67849114ecc2
# 7154584  33bb068b-2254-4cfb-b963-9944195de6b1
# 6560355  96921920-48f0-4b9c-86cf-ca51efa44961
# 7470837  a3bd4b58-57b9-4eda-88f2-4d27b08751cd
#
#                                  user_session                event_time  \
# 501019   aa044ff4-3a74-4fd8-b68b-9b0c9a3fe1e8 2019-11-01 00:00:17+00:00
# 1166610  09c35385-b085-498c-8828-615f6e7c147b 2019-11-01 00:01:21+00:00
# 1166611  09c35385-b085-498c-8828-615f6e7c147b 2019-11-01 00:01:41+00:00
# 1166612  09c35385-b085-498c-8828-615f6e7c147b 2019-11-01 00:02:44+00:00
# 1204577  2a5ee8b6-a608-4f09-b558-0e2351cb6bf2 2019-11-01 00:04:05+00:00
# ...                                       ...                       ...
# 7704253  fb90940d-3889-47c9-8287-72cf1fe79cb7 2020-02-15 14:41:08+00:00
# 7963432  ecd3353f-3bcb-4790-8a46-1a7cbf262dab 2020-02-15 14:41:08+00:00
# 7154584  450a994f-7187-4ebe-81ed-a931b01edb95 2020-02-15 14:41:09+00:00
# 6560355  b16650b1-b473-4d2b-9160-c590fa5c6ee9 2020-02-15 14:41:11+00:00
# 7470837  9d77f0c6-486d-48b8-8f22-826754825c1b 2020-02-15 14:41:11+00:00
#
#                  category_code     brand   price event_type  user_idx  \
# 501019          apparel.tshirt  goodloot    8.73       view     55450
# 1166610          apparel.shirt    jordan  102.71       view     98037
# 1166611          apparel.shirt    jordan  102.71       view     98037
# 1166612       apparel.trousers    jordan   83.53       view     98037
# 1204577          apparel.shoes    rooman   48.39       view     98037
# ...                        ...       ...     ...        ...       ...
# 7704253     apparel.shoes.keds  moulinex  154.42       view    575314
# 7963432     apparel.shoes.keds     ryobi    9.91       view     60689
# 7154584       apparel.trousers      nika   72.02       view    425160
# 6560355      apparel.underwear      cort  204.64       view    535421
# 7470837  apparel.shoes.sandals    chanel  203.88       view     19955
#
#          item_idx
# 501019       3944
# 1166610       279
# 1166611       507
# 1166612       508
# 1204577      1176
# ...           ...
# 7704253      8115
# 7963432     26077
# 7154584      7916
# 6560355      8229
# 7470837     10843
#
# [7515279 rows x 10 columns]

# %%
test_df
# Out:
#                                       user_id  \
# 6561914  fc641a3d-e641-4ada-b4be-a079e77dcdf9
# 7769629  69de41b4-032a-4639-b28a-34e7fbee93c4
# 7061597  09c1cd2e-f4df-49bd-aa95-9b174897cd65
# 8252034  bd661d5c-3083-4581-8490-62826f8393a8
# 8234347  a33debb1-bac3-482c-92cf-c63ff9939e01
# ...                                       ...
# 7131441  0d4a7ff3-0647-41a8-9176-3775747c10a0
# 7388009  1ceab7d4-aa38-449e-bdd3-3f96230c2d8d
# 6846768  497f6916-d368-4d19-b58c-30a0ef456523
# 7718564  1b489326-9e05-492e-bdcd-2c52c586c4db
# 8175077  d90757c4-2138-472d-8738-f37a5f98b267
#
#                                       item_id  \
# 6561914  1dc96fe9-67b0-4088-90f4-61f5c505091d
# 7769629  a5bfa0e6-13cb-4591-b469-100ec7dceba2
# 7061597  ac1c1bbd-5085-48ef-a79e-4ca07d1cec00
# 8252034  2dbd91ae-cc82-4cc2-9185-3688a3580ca6
# 8234347  0f979de9-7307-462c-8d32-0ce0142e91c4
# ...                                       ...
# 7131441  b092fe8f-6252-4a33-ba99-7e4ad94c5a49
# 7388009  b91deebf-3570-4ad8-91f0-c6186d94952a
# 6846768  d347a160-b39d-4819-bd9f-858df21b3039
# 7718564  5b071914-719c-4a73-bbd1-ab8100ba1eb2
# 8175077  fa8de887-2e69-4ed0-8aaf-9c984c4ab9e1
#
#                                  user_session                event_time  \
# 6561914  6f4ff885-5eaa-41f8-9717-89539e969387 2020-02-15 14:41:12+00:00
# 7769629  6a80fec8-0496-4bda-a42d-2b1fa31459cd 2020-02-15 14:41:12+00:00
# 7061597  aff4281a-2120-4797-a685-69b91777961a 2020-02-15 14:41:12+00:00
# 8252034  cab130a6-9080-4eef-ad23-9bbf347fd76e 2020-02-15 14:41:13+00:00
# 8234347  be6d9255-2dc6-405b-9882-fba4cd636651 2020-02-15 14:41:13+00:00
# ...                                       ...                       ...
# 7131441  5018b74a-0372-4565-9699-f77540906dd3 2020-02-29 23:57:34+00:00
# 7388009  016f8cdf-bd1d-4c3c-90d8-408dc6531815 2020-02-29 23:58:52+00:00
# 6846768  160fc029-47ac-42d4-aea5-f6c3aa9904c9 2020-02-29 23:59:02+00:00
# 7718564  7b331cb4-374e-478f-8cc7-d3a61b690756 2020-02-29 23:59:28+00:00
# 8175077  8b8ad2df-e243-47cd-b721-18cc547841aa 2020-02-29 23:59:33+00:00
#
#                    category_code     brand   price event_type  user_idx  \
# 6561914    apparel.shoes.slipons     apple  385.85       view    292023
# 7769629       apparel.shoes.keds    lamart   31.40       view    107783
# 7061597            apparel.shoes      sony  489.05       view    286471
# 8252034  apparel.shoes.moccasins   philips   46.26       view    541561
# 8234347       apparel.shoes.keds   kenwood  185.31       view    383095
# ...                          ...       ...     ...        ...       ...
# 7131441          apparel.costume   defacto   17.99       view     78755
# 7388009            apparel.shirt   similac    7.69       view    557472
# 6846768            apparel.shoes  starline  165.51       view    389775
# 7718564            apparel.shoes   samsung   25.46       view    588654
# 8175077            apparel.shoes   incanto  100.36       view     77509
#
#          item_idx
# 6561914      7914
# 7769629     21548
# 7061597     14195
# 8252034      8668
# 8234347      8952
# ...           ...
# 7131441     27411
# 7388009     13031
# 6846768      8331
# 7718564      7818
# 8175077     11671
#
# [835032 rows x 10 columns]

# %%
test_df = test_df[test_df["event_type"]=="purchase"] # purchase interactions
test_df = test_df[["user_idx", "item_idx"]] # for evaluation

# %%
test_df.head()
# Out:
#          user_idx  item_idx
# 7248906    136652     26319
# 7968656    585314      7946
# 6953945    275223      7730
# 8283240    482940      7818
# 7719234     21867      7977

# %%
# 사용자-아이템 간 상호작용을 나타내는 이진 레이블 열 추가
train_df["label"] = 1

# 사용자-아이템 행렬 생성을 위해 사용자 인덱스, 아이템 인덱스, 레이블을 기준으로 그룹화
# WRMF의 confidence value를 user x item 상호작용 횟수로 설정함 (label=1 값을 더하므로)
user_item_matrix = train_df.groupby(["user_idx", "item_idx"])["label"].sum().reset_index()

# %% [markdown]
# ## 4. Modeling

# %%
# 사용자-아이템 상호작용 행렬을 희소 행렬로 변환
sparse_user_item = sparse.csr_matrix(
                    (user_item_matrix["label"].values,
                    (user_item_matrix["user_idx"].values,
                    user_item_matrix["item_idx"].values)),
                    shape=(len(user2idx), len(item2idx)),
                    dtype=np.float32)
sparse_user_item = sparse_user_item.tocsr()

# 모델 파라미터 설정
num_factor = 8 # 128, 256, 512, 1024 까지 늘려 보세요
regularization = 0.001 # 1e-5, 5e-5, 1e-4, 5e-4, 1e-3 등 다양한 값으로 실험해보세요.
alpha = 1 # 위에서 confidence 값을 sparse_matrix에 넣어주는 형태로 처리했지만, alpha도 자체적으로 수정할 수 있습니다.

# %%
# Implicit 라이브러리의 Alternating Least Squares 모델 파라미터 설정
model = AlternatingLeastSquares(
    factors=num_factor,
    regularization=regularization,
    alpha=alpha,
    use_gpu=False) # colab implicit 호환 이슈로 False로 설정되어 있습니다. 가능하면 use_gpu=True로 설정해주세요.

model.fit(sparse_user_item)
# Out:
# /usr/local/lib/python3.10/dist-packages/implicit/cpu/als.py:95: RuntimeWarning: OpenBLAS is configured to use 8 threads. It is highly recommended to disable its internal threadpool by setting the environment variable 'OPENBLAS_NUM_THREADS=1' or by calling 'threadpoolctl.threadpool_limits(1, "blas")'. Having OpenBLAS use a threadpool can lead to severe performance issues here.
#   check_blas_config()
#   0%|          | 0/15 [00:00<?, ?it/s]

# %% [markdown]
# ## 5. Evaluation on the Validation Set

# %%
import numpy as np

def get_ndcg(relevant_items, recommend_items, k=10):
    """
    NDCG를 계산하는 함수입니다.
    :param relevant_items: 사용자가 실제로 선호하는 아이템 리스트
    :param recommend_items: 모델이 추천한 아이템 리스트
    :param k: 고려할 상위 아이템의 수
    :return: 계산된 NDCG 값
    """
    dcg = 0.0
    idcg = 0.0
    for i, item in enumerate(recommend_items[:k]):
        if item in relevant_items:
            dcg += 1.0 / np.log2(i + 2)
        idcg += 1.0 / np.log2(i + 2)

    ndcg = dcg / idcg if idcg > 0 else 0.0
    return ndcg

# %%
# user_idx 별로 item_idx의 list를 Dict[user_idx, List[item_idx]] 형태로 변환
test_dict = test_df.groupby("user_idx")["item_idx"].apply(list).to_dict()

# %%
# test_dict

# %%
top_k = 10
ndcgs = []

for user_idx, ground_truth in tqdm(test_dict.items()):
    recommended_items, scores = model.recommend(user_idx, sparse_user_item[user_idx], N=top_k, filter_already_liked_items=False)
    ndcgs.append(get_ndcg(ground_truth, recommended_items))

print(f'\nndcg@{top_k}: {np.mean(ndcgs)}')
# most_popular_10의 NDCG@10이 0.06 가량이므로 현재 ALS의 성능인 0.0249은 매우 좋지 않은 성능임
# 코랩 실습 환경 상 GPU와 implicit 라이브러리 호환이 잘 되지 않는 관계로 매우 작은 값의 hyperparameter를 사용하고 있음 (factors=8)
# ALS에서 사용하는 factors, regularization, confidence 등의 hyperparameters를 변경하거나, 사용하는 데이터의의 양 등을 조정해서
# 더 좋은 성능을 얻을 수 있도록 다양한 방향으로 실험해봅시다.
# Out:
# 100%|██████████| 1122/1122 [00:00<00:00, 1354.92it/s]
# ndcg@10: 0.025524295717384963

# %% [markdown]
# ## 6. Inference & Save Submission File
#
# 위에서 충분한 실험을 진행하고 최종 모델을 선정했으면, 해당 모델로 제출용 파일을 생성해야 합니다. 여기에서는 편의상 위의 `model`로 제출 파일 생성을 진행해보겠습니다.

# %%
# 테스트에 사용될 사용자 인덱스 추출
test_users_idx = np.array(train_df['user_idx'].unique())
# 사용자 별로 top 10개를 생성해야 하므로 submission.csv 포맷에 맞추기 위해서 동일 user_id를 10개씩 미리 리스트에 생성
"""
user_id, item_id
A      ,  214
A      ,  126
...
A      ,  594
B      ,  906
B      ,  745
...
"""
test_users_idx_list = [num for num in test_users_idx for _ in range(top_k)]

# 모델을 사용하여 테스트 사용자에 대한 추천 아이템 목록 생성
outputs = model.recommend(test_users_idx, sparse_user_item[test_users_idx], N=top_k, filter_already_liked_items=False)
recommend_items = outputs[0]

# 추천 결과를 데이터프레임으로 변환하고, 사용자 및 아이템 인덱스를 실제 사용자와 아이템 값으로 매핑
sub_df = pd.DataFrame({'user_id': test_users_idx_list, 'item_id': recommend_items.flatten()})
sub_df['user_id'] = sub_df['user_id'].map(idx2user)
sub_df['item_id'] = sub_df['item_id'].map(idx2item)

# 결과를 CSV 파일로 저장
outfile = "output.csv"
sub_df.to_csv(outfile, index=False)

# %%
# !head /content/output.csv
# Out:
# user_id,item_id
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,7cb77677-2b87-429e-aea8-e80bce238747
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,fb3337d1-220c-4ff6-a8b4-f0c35d0a9e15
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,d1f7b907-e3d8-4969-87f8-feebf46b0646
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,6993b754-dee7-4d14-b8a6-a2b9cc29a609
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,bcf948ae-0ed9-42a8-bb2a-ae5617315799
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,a609d2dd-aeed-4eaa-8928-d3a56bab5d0f
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,e89adbe4-6c31-40f2-a477-f3edb0a3ba1b
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,a3156bdc-2b1c-4c84-bf69-089aa2af3fc9
# 24d3ec59-5019-4edd-9cbc-1b33ae7808a4,fc411f61-2803-4f0e-ad37-0beb7596539f

# %% [markdown]
# ## Required Package
#
#
# implicit==0.7.21 <br>
# scipy==1.11.4 <br>
# numpy==1.23.5 <br>
# pandas==1.5.3 <br>
# tqdm==4.66.1 <br>

# %% [markdown]
# ## 콘텐츠 라이선스
#
# 저작권 : <font color='blue'> <b> ©2023 by Upstage X fastcampus Co., Ltd. All rights reserved.</font></b>
#
# <font color='red'><b>WARNING</font> : 본 교육 콘텐츠의 지식재산권은 업스테이지 및 패스트캠퍼스에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다. </b>
